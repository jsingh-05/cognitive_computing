# %%
#A1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(102317177)
sales_data = np.random.randint(1000, 5001, size=(12, 4))
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']

sales_df = pd.DataFrame(sales_data, columns=categories, index=months)

print("First 5 Rows:\n", sales_df.head())
print("\nSummary Statistics:\n", sales_df.describe())

total_sales_category = sales_df.sum()
total_sales_month = sales_df.sum(axis=1)
print("\nTotal Sales per Category:\n", total_sales_category)
print("\nTotal Sales per Month:\n", total_sales_month)

avg_growth_category = sales_df.pct_change().mean() * 100
print("\nAverage Sales Growth (%) per Category:\n", avg_growth_category)

sales_df['Total Sales'] = total_sales_month
sales_df['Growth Rate (%)'] = sales_df['Total Sales'].pct_change() * 100
print("\nData with Total Sales and Growth Rate:\n", sales_df)

sales_df['Clothing'] = sales_df['Clothing'] * 0.85

print("\nData after applying discount:\n", sales_df)

plt.figure(figsize=(10,6))
for category in categories:
    if category in sales_df.columns:
        plt.plot(months, sales_df[category], label=category)

plt.title('Monthly Sales Trends by Category')
plt.xlabel('Month')
plt.ylabel('Sales Units')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8,6))
sns.boxplot(data=sales_df[categories])
plt.title('Sales Distribution by Category')
plt.xlabel('Category')
plt.ylabel('Sales Units')
plt.grid(True)
plt.show()
# Out:
# First 5 Rows:
#       Electronics  Clothing  Home & Kitchen  Sports
# Jan         2460      3200            1923    1650
# Feb         3255      4955            3868    1646
# Mar         2216      3585            1152    4869
# Apr         3339      1778            2072    1503
# May         4606      4299            3764    2271
#
# Summary Statistics:
#         Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000        12.00000    12.000000
# mean   2901.833333  2687.583333      3044.50000  3189.166667
# std    1123.391604  1205.443295      1144.85271  1218.441839
# min    1310.000000  1047.000000      1152.00000  1503.000000
# 25%    2351.000000  1707.000000      2040.50000  2115.750000
# 50%    2647.500000  2667.000000      3402.00000  3339.500000
# 75%    3393.750000  3296.250000      3930.00000  3953.250000
# max    4993.000000  4955.000000      4589.00000  4954.000000
#
# Total Sales per Category:
#  Electronics       34822
# ...

# %%
#A2
array = np.array([[1, -2, 3], [-4, 5, -6]])

abs_array = np.abs(array)
print("\nAbsolute Value:\n", abs_array)

flattened_array = array.flatten()
percentiles_flat = np.percentile(flattened_array, [25, 50, 75])
percentiles_columns = np.percentile(array, [25, 50, 75], axis=0)
percentiles_rows = np.percentile(array, [25, 50, 75], axis=1)

print("\n25th, 50th, 75th Percentiles (Flattened):\n", percentiles_flat)
print("\nPercentiles (Each Column):\n", percentiles_columns)
print("\nPercentiles (Each Row):\n", percentiles_rows)

mean_flat = np.mean(flattened_array)
median_flat = np.median(flattened_array)
std_flat = np.std(flattened_array)

mean_cols = np.mean(array, axis=0)
median_cols = np.median(array, axis=0)
std_cols = np.std(array, axis=0)

mean_rows = np.mean(array, axis=1)
median_rows = np.median(array, axis=1)
std_rows = np.std(array, axis=1)

print("\nMean, Median, Std of Flattened Array:\n", mean_flat, median_flat, std_flat)
print("\nMean, Median, Std of Columns:\n", mean_cols, median_cols, std_cols)
print("\nMean, Median, Std of Rows:\n", mean_rows, median_rows, std_rows)
# Out:
# Absolute Value:
#  [[1 2 3]
#  [4 5 6]]
#
# 25th, 50th, 75th Percentiles (Flattened):
#  [-3.5 -0.5  2.5]
#
# Percentiles (Each Column):
#  [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
#
# Percentiles (Each Row):
#  [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
#
# Mean, Median, Std of Flattened Array:
#  -0.5 -0.5 3.8622100754188224
#
# Mean, Median, Std of Columns:
#  [-1.5  1.5 -1.5] [-1.5  1.5 -1.5] [2.5 3.5 4.5]
#
# Mean, Median, Std of Rows:
#  [ 0.66666667 -1.66666667] [ 1. -4.] [2.05480467 4.78423336]

# %%
#A3
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])

floor_values = np.floor(a)
ceil_values = np.ceil(a)
trunc_values = np.trunc(a)
round_values = np.round(a)

print("\nFloor Values:\n", floor_values)
print("\nCeiling Values:\n", ceil_values)
print("\nTruncated Values:\n", trunc_values)
print("\nRounded Values:\n", round_values)
# Out:
# Floor Values:
#  [-2. -2. -1.  0.  1.  1.  3.]
#
# Ceiling Values:
#  [-1. -1. -0.  1.  2.  2.  3.]
#
# Truncated Values:
#  [-1. -1. -0.  0.  1.  1.  3.]
#
# Rounded Values:
#  [-2. -2. -0.  0.  2.  2.  3.]

# %%
#A4
lst = [1, 2, 3, 4, 5]
temp = lst[1]
lst[1] = lst[3]
lst[3] = temp
print("\nList after swapping 2nd and 4th elements:\n", lst)
# Out:
# List after swapping 2nd and 4th elements:
#  [1, 4, 3, 2, 5]

# %%
#A5
s = {10, 20, 30, 40, 50}
s_list = list(s)

temp = s_list[1]
s_list[1] = s_list[3]
s_list[3] = temp

s_swapped = set(s_list)
print("\nSet after swapping elements:\n", s_swapped)
# Out:
# Set after swapping elements:
#  {40, 10, 50, 20, 30}
